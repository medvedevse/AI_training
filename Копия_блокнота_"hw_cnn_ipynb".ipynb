# %% [markdown]
# <a href="https://colab.research.google.com/github/medvedevse/AI_training/blob/main/%D0%9A%D0%BE%D0%BF%D0%B8%D1%8F_%D0%B1%D0%BB%D0%BE%D0%BA%D0%BD%D0%BE%D1%82%D0%B0_%22hw_cnn_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Домашнее задание. Сверточные нейронные сети (10 баллов)
# В этом домашнем задании вы потренируетесь в построении полносвязных и сверточных нейронных сетей. Мы сравним качество нейросетей на датасете MNIST с рукописными цифрами. Наша цель --- построить нейронную сеть для решения задачи классификации цифр на 10 классов.
#
# ## Оценивание задания
# Это задание будет проверяться в формате peer-review. Это означает, что вашу посылку на Stepik будут проверять 3 других учащихся, и медианное значение их оценок будет выставлено в качестве окончательного балла. Чтобы получить баллы, вам также нужно будет проверить трех других учеников. Это станет доступно после того, как вы сдадите задание сами.
#
# ## Оформление посылки
# В качестве решения необходимо послать ноутбук в формате .ipynb. Пожалуйста, сделайте файл максимально читаемым. Если размер вашего файла превышает 5 Мб, приложите текстовый документ со ссылкой на файл в Google Drive (не забудьте обеспечить доступ на чтение). Пожалуйста, проследите, чтобы у файла было верное расширение: иначе у других участников могут возникнуть проблемы с прочтением.
#
# ## Рекомендации по решению
# Подробные критерии проверки станут доступными во время проверки на Stepik. Пока мы предлагаем несколько правил, которые помогут вам набрать максимальное количество баллов.
# * Сначала оформите ноутбук, а затем перезапустите среду выполнения и выполните ноутбук заново (Среда выполнения→перезапустить и выполнить всё). Так вы убедитесь, что итоговый код вашего ноутбука корректен.
# * В ноутбуке есть два типа проверки: 2 `assert`'а и 4 ключевых вопроса. Корректное решение должно проходить все `assert`-ы. Также необходимо дать ответы на все вопросы из ноутбука.
# * Чем более понятным и читаемым вы сделаете код, тем больше шансов, что проверяющий поставит вам за него высокий балл.
#
# Желаем удачи!

# %%
import numpy as np

import seaborn as sns
from matplotlib import pyplot as plt

from sklearn.datasets import make_moons
from sklearn.model_selection import train_test_split

import torch
from torch import nn
from torch.nn import functional as F

import torchvision.transforms as tfs

from torch.utils.data import TensorDataset, DataLoader

sns.set(style="darkgrid", font_scale=1.4)

# %% [markdown]
# ## Датасет MNIST
# Датасет MNIST содержит рукописные цифры. Загрузим датасет и создадим DataLoader-ы. Пример можно найти в семинаре по полносвязным нейронным сетям.

# %%
import os
from torchvision.datasets import MNIST

data_tfs = tfs.Compose([
    tfs.ToTensor(),
    tfs.Normalize((0.5), (0.5))
])

# install for train and test
root = './'
train_dataset = MNIST(root, train=True,  transform=data_tfs, download=True)
val_dataset  = MNIST(root, train=False, transform=data_tfs, download=True)

train_dataloader = DataLoader(train_dataset, batch_size=128, shuffle=True, pin_memory=True, num_workers=2) # YOUR CODE GOES HERE
valid_dataloader = DataLoader(val_dataset, batch_size=128, shuffle=False) # YOUR CODE GOES HERE
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ./MNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 9912422/9912422 [00:00<00:00, 93282666.31it/s]
# Extracting ./MNIST/raw/train-images-idx3-ubyte.gz to ./MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ./MNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 28881/28881 [00:00<00:00, 47263243.79it/s]
# Extracting ./MNIST/raw/train-labels-idx1-ubyte.gz to ./MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ./MNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 1648877/1648877 [00:00<00:00, 25848388.36it/s]
# Extracting ./MNIST/raw/t10k-images-idx3-ubyte.gz to ./MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ./MNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4542/4542 [00:00<00:00, 6199325.99it/s]
# Extracting ./MNIST/raw/t10k-labels-idx1-ubyte.gz to ./MNIST/raw

# %% [markdown]
# ## Часть 1. Полносвязные нейронные сети (3 балла)
# Сначала решим MNIST с помощью полносвязной нейронной сети.

# %% [markdown]
# ### Задание. Простая полносвязная нейронная сеть (1 балл)
#
# Создайте полносвязную нейронную сеть с помощью класса Sequential. Сеть состоит из:
# * Уплощения матрицы в вектор (nn.Flatten);
# * Двух скрытых слоёв из 128 нейронов с активацией nn.ELU;
# * Выходного слоя с 10 нейронами.
#
# Задайте функцию потерь для обучения (кросс-энтропия).

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

# %%
activation = nn.ELU

model = nn.Sequential(
    nn.Flatten(),
    nn.Linear(784, 128),
    activation(),
    nn.Linear(128, 10),
    
    #YOUR CODE. Add layers to your sequential class
).to(device)

# %%
criterion = torch.nn.CrossEntropyLoss() #YOUR CODE. Select a loss function
optimizer = torch.optim.Adam(model.parameters())

loaders = {"train": train_dataloader, "valid": valid_dataloader}

# %% [markdown]
# ### Train loop (seriously)
#
# Давайте разберемся с кодом ниже, который подойдет для 90% задач в будущем.
#
#
# ```python
# for epoch in range(max_epochs):  # <--------------- итерируемся по датасету несколько раз
#     for k, dataloader in loaders.items():  # <----- несколько dataloader для train / valid / test
#         for x_batch, y_batch in dataloader:  # <--- итерируемся по датасету. Так как мы используем SGD а не GD, то берем батчи заданного размера
#             if k == "train":
#                 model.train()  # <------------------ переводим модель в режим train
#                 optimizer.zero_grad()  # <--------- обнуляем градиенты модели
#                 outp = model(x_batch)
#                 loss = criterion(outp, y_batch) # <-считаем "лосс" для логистической регрессии
#                 loss.backward()  # <--------------- считаем градиенты
#                 optimizer.step()  # <-------------- делаем шаг градиентного спуска
#             else:  # <----------------------------- test/eval
#                 model.eval()  # <------------------ переводим модель в режим eval
#                 with torch.no_grad():  # <--------- НЕ считаем градиенты
#                     outp = model(x_batch)  # <------------- получаем "логиты" из модели
#             count_metrics(outp, y_batch)  # <-------------- считаем метрики
# ```

# %% [markdown]
# ### Задание. Дополните цикл обучения (1 балл)

# %%
max_epochs = 10
accuracy = {"train": [], "valid": []}
for epoch in range(max_epochs):
    for k, dataloader in loaders.items():
        epoch_correct = 0
        epoch_all = 0
        for x_batch, y_batch in dataloader:
            x_batch = x_batch.to(device)
            y_batch = y_batch.to(device)
            if k == "train":
                model.train()
                optimizer.zero_grad()
                outp = model(x_batch)
                 # YOUR CODE. Set model to ``train`` mode and calculate outputs. Don't forget zero_grad!
            else:
            
                model.eval()
                with torch.no_grad():
                    outp = model(x_batch) # YOUR CODE. Set model to ``eval`` mode and calculate outputs
            preds = outp.argmax(-1)
            correct = (preds == y_batch).sum() # YOUR CODE GOES HERE
            all = y_batch.size(0) # YOUR CODE GOES HERE
            epoch_correct += correct.item()
            epoch_all += all
            if k == "train":
                loss = criterion(outp, y_batch)
                loss.backward()
                optimizer.step()
                # YOUR CODE. Calculate gradients and make a step of your optimizer
        if k == "train":
            print(f"Epoch: {epoch+1}")
        print(f"Loader: {k}. Accuracy: {epoch_correct/epoch_all}")
        accuracy[k].append(epoch_correct/epoch_all)
# Out:
# Epoch: 1
# Loader: train. Accuracy: 0.87975
# Loader: valid. Accuracy: 0.9283
# Epoch: 2
# Loader: train. Accuracy: 0.9372666666666667
# Loader: valid. Accuracy: 0.9518
# Epoch: 3
# Loader: train. Accuracy: 0.9572333333333334
# Loader: valid. Accuracy: 0.9623
# Epoch: 4
# Loader: train. Accuracy: 0.9659
# Loader: valid. Accuracy: 0.9684
# Epoch: 5
# Loader: train. Accuracy: 0.9723
# Loader: valid. Accuracy: 0.9707
# Epoch: 6
# Loader: train. Accuracy: 0.97625
# Loader: valid. Accuracy: 0.9734
# Epoch: 7
# Loader: train. Accuracy: 0.9796333333333334
# Loader: valid. Accuracy: 0.9722
# Epoch: 8
# Loader: train. Accuracy: 0.9819166666666667
# Loader: valid. Accuracy: 0.9748
# Epoch: 9
# Loader: train. Accuracy: 0.9834833333333334
# Loader: valid. Accuracy: 0.9724
# Epoch: 10
# Loader: train. Accuracy: 0.9851
# Loader: valid. Accuracy: 0.9711

# %%
elu_accuracy = accuracy["valid"]

# %%
assert elu_accuracy[-1] > 0.97, 'Модель недостаточно хорошая. Нужно искать ошибку!'

# %% [markdown]
# ### Задание. Протестируйте разные функции активации (1 балл)
# Попробуйте разные функции активации. Для каждой функции активации посчитайте массив validation accuracy. Лучше реализовать это в виде функции, берущей на вход активацию и получающей массив из accuracies.
#
# Вам необходимо попробовать следующие функции активации:
# * тождественная функция активации $f(x) = x$ (класс Identical реализован за вас ниже)
# * сигмоида;
# * ReLU;
# * Leaky ReLU;
# * Tanh (гиперболический тангенс).

# %%
# YOUR CODE. Do the same thing with other activations (it's better to wrap into a function that returns a list of accuracies)
sigm = nn.Sigmoid
relu = nn.ReLU
leaky = nn.LeakyReLU
tanh = nn.Tanh

# %%
class Identical(nn.Module):
    def forward(self, x):
        return x

# %%
def model_cnn(func):
    model = nn.Sequential(
        nn.Flatten(),
        nn.Linear(784, 128),
        func(),
        nn.Linear(128, 10),
    ).to(device)
    return model

# %%
def test_activation_function(func):
    net = model_cnn(func)
    criterion = torch.nn.CrossEntropyLoss() #YOUR CODE. Select a loss function
    optimizer = torch.optim.Adam(net.parameters())

    loaders = {"train": train_dataloader, "valid": valid_dataloader}
    max_epochs = 10
    accuracy = {"train": [], "valid": []}
    for epoch in range(max_epochs):
        for k, dataloader in loaders.items():
            epoch_correct = 0
            epoch_all = 0
            for x_batch, y_batch in dataloader:
                x_batch = x_batch.to(device)
                y_batch = y_batch.to(device)
                if k == "train":
                    net.train()
                    optimizer.zero_grad()
                    outp = net(x_batch)
                 # YOUR CODE. Set model to ``train`` mode and calculate outputs. Don't forget zero_grad!
                else:
                    net.eval()
                    with torch.no_grad():
                        outp = net(x_batch) # YOUR CODE. Set model to ``eval`` mode and calculate outputs
                preds = outp.argmax(-1)
                correct = (preds == y_batch).sum() # YOUR CODE GOES HERE
                all = y_batch.size(0) # YOUR CODE GOES HERE
                epoch_correct += correct.item()
                epoch_all += all
                if k == "train":
                    loss = criterion(outp, y_batch)
                    loss.backward()
                    optimizer.step()
                # YOUR CODE. Calculate gradients and make a step of your optimizer
            if k == "train":
                print(f"Epoch: {epoch+1}")
            print(f"Loader: {k}. Accuracy: {epoch_correct/epoch_all}")
            accuracy[k].append(epoch_correct/epoch_all)

    return accuracy["valid"]

# %%
plain_accuracy = test_activation_function(Identical)
sigmoid_accuracy = test_activation_function(sigm) #YOUR CODE
relu_accuracy = test_activation_function(relu) #YOUR CODE
leaky_relu_accuracy = test_activation_function(leaky) #YOUR CODE
tanh_accuracy = test_activation_function(tanh) #YOUR CODE

print('plain_accuracy:', plain_accuracy[-1])
print('sigmoid_accuracy:', sigmoid_accuracy[-1])
print('relu_accuracy:', relu_accuracy[-1])
print('leaky_relu_accuracy:', leaky_relu_accuracy[-1])
print('tanh_accuracy:', tanh_accuracy[-1])
# Out:
# Epoch: 1
# Loader: train. Accuracy: 0.8722
# Loader: valid. Accuracy: 0.911
# Epoch: 2
# Loader: train. Accuracy: 0.90665
# Loader: valid. Accuracy: 0.9038
# Epoch: 3
# Loader: train. Accuracy: 0.9097
# Loader: valid. Accuracy: 0.9218
# Epoch: 4
# Loader: train. Accuracy: 0.9116
# Loader: valid. Accuracy: 0.9153
# Epoch: 5
# Loader: train. Accuracy: 0.9155666666666666
# Loader: valid. Accuracy: 0.9141
# Epoch: 6
# Loader: train. Accuracy: 0.91485
# Loader: valid. Accuracy: 0.9176
# Epoch: 7
# Loader: train. Accuracy: 0.9167333333333333
# Loader: valid. Accuracy: 0.912
# Epoch: 8
# Loader: train. Accuracy: 0.9169666666666667
# Loader: valid. Accuracy: 0.9124
# Epoch: 9
# Loader: train. Accuracy: 0.9183
# Loader: valid. Accuracy: 0.9147
# Epoch: 10
# Loader: train. Accuracy: 0.9184
# Loader: valid. Accuracy: 0.9223
# Epoch: 1
# Loader: train. Accuracy: 0.86075
# Loader: valid. Accuracy: 0.9209
# Epoch: 2
# Loader: train. Accuracy: 0.9246333333333333
# Loader: valid. Accuracy: 0.9347
# Epoch: 3
# Loader: train. Accuracy: 0.9393666666666667
# Loader: valid. Accuracy: 0.9478
# Epoch: 4
# Loader: train. Accuracy: 0.9503666666666667
# Loader: valid. Accuracy: 0.9511
# Epoch: 5
# Loader: train. Accuracy: 0.95805
# Loader: valid. Accuracy: 0.9558
# Epoch: 6
# Loader: train. Accuracy: 0.96365
# Loader: valid. Accuracy: 0.9621
# Epoch: 7
# Loader: train. Accuracy: 0.9681666666666666
# Loader: valid. Accuracy: 0.9655
# Epoch: 8
# Loader: train. Accuracy: 0.9722666666666666
# Loader: valid. Accuracy: 0.9676
# Epoch: 9
# Loader: train. Accuracy: 0.9758166666666667
# Loader: valid. Accuracy: 0.9699
# Epoch: 10
# Loader: train. Accuracy: 0.9782
# Loader: valid. Accuracy: 0.9708
# Epoch: 1
# Loader: train. Accuracy: 0.8720666666666667
# Loader: valid. Accuracy: 0.9194
# Epoch: 2
# Loader: train. Accuracy: 0.9292
# Loader: valid. Accuracy: 0.9417
# Epoch: 3
# Loader: train. Accuracy: 0.9476166666666667
# Loader: valid. Accuracy: 0.9561
# Epoch: 4
# Loader: train. Accuracy: 0.9595333333333333
# Loader: valid. Accuracy: 0.9592
# Epoch: 5
# Loader: train. Accuracy: 0.96665
# Loader: valid. Accuracy: 0.9627
# Epoch: 6
# Loader: train. Accuracy: 0.9715333333333334
# Loader: valid. Accuracy: 0.9688
# Epoch: 7
# Loader: train. Accuracy: 0.9740833333333333
# Loader: valid. Accuracy: 0.9699
# Epoch: 8
# Loader: train. Accuracy: 0.97695
# Loader: valid. Accuracy: 0.9688
# Epoch: 9
# Loader: train. Accuracy: 0.9788166666666667
# Loader: valid. Accuracy: 0.9673
# Epoch: 10
# Loader: train. Accuracy: 0.9807333333333333
# Loader: valid. Accuracy: 0.9715
# Epoch: 1
# Loader: train. Accuracy: 0.8776
# Loader: valid. Accuracy: 0.9183
# Epoch: 2
# Loader: train. Accuracy: 0.93065
# Loader: valid. Accuracy: 0.9445
# Epoch: 3
# Loader: train. Accuracy: 0.9505166666666667
# Loader: valid. Accuracy: 0.9538
# Epoch: 4
# Loader: train. Accuracy: 0.9608166666666667
# Loader: valid. Accuracy: 0.963
# Epoch: 5
# Loader: train. Accuracy: 0.9670166666666666
# Loader: valid. Accuracy: 0.9639
# Epoch: 6
# Loader: train. Accuracy: 0.9704833333333334
# Loader: valid. Accuracy: 0.9687
# Epoch: 7
# Loader: train. Accuracy: 0.9746166666666667
# Loader: valid. Accuracy: 0.9683
# Epoch: 8
# Loader: train. Accuracy: 0.9776666666666667
# Loader: valid. Accuracy: 0.9739
# Epoch: 9
# Loader: train. Accuracy: 0.9790833333333333
# Loader: valid. Accuracy: 0.9741
# Epoch: 10
# Loader: train. Accuracy: 0.9822833333333333
# Loader: valid. Accuracy: 0.9711
# Epoch: 1
# Loader: train. Accuracy: 0.8874666666666666
# Loader: valid. Accuracy: 0.9308
# Epoch: 2
# Loader: train. Accuracy: 0.9419833333333333
# Loader: valid. Accuracy: 0.9501
# Epoch: 3
# Loader: train. Accuracy: 0.9568166666666666
# Loader: valid. Accuracy: 0.9586
# Epoch: 4
# Loader: train. Accuracy: 0.96555
# Loader: valid. Accuracy: 0.9639
# Epoch: 5
# Loader: train. Accuracy: 0.97115
# Loader: valid. Accuracy: 0.9664
# Epoch: 6
# Loader: train. Accuracy: 0.9747666666666667
# Loader: valid. Accuracy: 0.9664
# Epoch: 7
# Loader: train. Accuracy: 0.97815
# Loader: valid. Accuracy: 0.9706
# Epoch: 8
# Loader: train. Accuracy: 0.9792666666666666
# Loader: valid. Accuracy: 0.9735
# Epoch: 9
# Loader: train. Accuracy: 0.9827333333333333
# Loader: valid. Accuracy: 0.9741
# Epoch: 10
# Loader: train. Accuracy: 0.9846333333333334
# Loader: valid. Accuracy: 0.9735
# plain_accuracy: 0.9223
# sigmoid_accuracy: 0.9708
# relu_accuracy: 0.9715
# leaky_relu_accuracy: 0.9711
# tanh_accuracy: 0.9735

# %% [markdown]
# ### Accuracy
# Построим график accuracy/epoch для каждой функции активации.

# %%
sns.set(style="darkgrid", font_scale=1.4)

plt.figure(figsize=(16, 10))
plt.title("Valid accuracy")
plt.plot(range(max_epochs), plain_accuracy, label="No activation", linewidth=2)
plt.plot(range(max_epochs), sigmoid_accuracy, label="Sigmoid activation", linewidth=2)
plt.plot(range(max_epochs), relu_accuracy, label="ReLU activation", linewidth=2)
plt.plot(range(max_epochs), leaky_relu_accuracy, label="LeakyReLU activation", linewidth=2)
plt.plot(range(max_epochs), elu_accuracy, label="ELU activation", linewidth=2)
plt.plot(range(max_epochs), tanh_accuracy, label="Tanh activation", linewidth=2)

plt.legend()
plt.xlabel("Epoch")
plt.show()

# %%
plt.figure(figsize=(16, 10))
plt.title("Valid accuracy")
plt.plot(range(max_epochs), relu_accuracy, label="ReLU activation", linewidth=2)
plt.plot(range(max_epochs), leaky_relu_accuracy, label="LeakyReLU activation", linewidth=2)
plt.plot(range(max_epochs), elu_accuracy, label="ELU activation", linewidth=2)
plt.plot(range(max_epochs), tanh_accuracy, label="Tanh activation", linewidth=2)
plt.legend()
plt.xlabel("Epoch")
plt.show()

# %% [markdown]
# **Вопрос 1.** Какая из активаций показала наивысший `accuracy` к концу обучения?
#
# **Ответ:** Tanh

# %% [markdown]
# ## Часть 2 Сверточные нейронные сети (7 баллов)

# %% [markdown]
# ### Ядра (1 балл)
# Сначала немного поработам с самим понятием ядра свёртки.

# %%
# !wget https://img.the-village.kz/the-village.com.kz/post-cover/5x5-I6oiwjmq79dMCZMEbA-default.jpg -O sample_photo.jpg
# Out:
# --2023-06-05 19:04:45--  https://img.the-village.kz/the-village.com.kz/post-cover/5x5-I6oiwjmq79dMCZMEbA-default.jpg
# Resolving img.the-village.kz (img.the-village.kz)... 144.76.208.75
# Connecting to img.the-village.kz (img.the-village.kz)|144.76.208.75|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://img.the-village-kz.com/the-village.com.kz/post-cover/5x5-I6oiwjmq79dMCZMEbA-default.jpg [following]
# --2023-06-05 19:04:46--  https://img.the-village-kz.com/the-village.com.kz/post-cover/5x5-I6oiwjmq79dMCZMEbA-default.jpg
# Resolving img.the-village-kz.com (img.the-village-kz.com)... 172.67.128.246, 104.21.1.92, 2606:4700:3036::ac43:80f6, ...
# Connecting to img.the-village-kz.com (img.the-village-kz.com)|172.67.128.246|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 49337 (48K) [image/jpeg]
# Saving to: ‘sample_photo.jpg’
#
# sample_photo.jpg    100%[===================>]  48.18K  --.-KB/s    in 0.01s
#
# 2023-06-05 19:04:47 (4.44 MB/s) - ‘sample_photo.jpg’ saved [49337/49337]

# %%
import cv2
sns.set(style="white")
img = cv2.imread("sample_photo.jpg")
RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(12, 8))
plt.imshow(RGB_img)
plt.show()

# %% [markdown]
# Попробуйте посмотреть как различные свертки влияют на фото. Например, попробуйте
# A)
# ```
# [0, 0, 0],
# [0, 1, 0],
# [0, 0, 0]
# ```
# Б)
# ```
# [0, 1, 0],
# [0, -2, 0],
# [0, 1, 0]
# ```
# В)
# ```
# [0, 0, 0],
# [1, -2, 1],
# [0, 0, 0]
# ```
# Г)
# ```
# [0, 1, 0],
# [1, -4, 1],
# [0, 1, 0]
# ```
# Д)
# ```
# [0, -1, 0],
# [-1, 5, -1],
# [0, -1, 0]
# ```
# Е)
# ```
# [0.0625, 0.125, 0.0625],
# [0.125, 0.25, 0.125],
# [0.0625, 0.125, 0.0625]
# ```
#
# Не стесняйтесь пробовать свои варианты!

# %%
img_t = torch.from_numpy(RGB_img).type(torch.float32).unsqueeze(0)
kernel = torch.tensor([
    [0, -1, 0],
    [-1, 5, -1],
    [0, -1, 0]
]).reshape(1, 1, 3, 3).type(torch.float32)

kernel = kernel.repeat(3, 3, 1, 1)
img_t = img_t.permute(0, 3, 1, 2)  # [BS, H, W, C] -> [BS, C, H, W]
img_t = nn.ReflectionPad2d(1)(img_t)  # Pad Image for same output size

result = F.conv2d(img_t, kernel)[0]  #

# %%
plt.figure(figsize=(12, 8))
result_np = result.permute(1, 2, 0).numpy() / 256 / 3

plt.imshow(result_np)
plt.show()
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# **Вопрос 2.** Как можно описать действия ядер, приведенных выше? Сопоставьте для каждой буквы число.
#
# 1) Размытие
#
# 2) Увеличение резкости
#
# 3) Тождественное преобразование
#
# 4) Выделение вертикальных границ
#
# 5) Выделение горизонтальных границ
#
# 6) Выделение границ
#
# **Ответ:**
# А - 3,
# Б - 5,
# В - 4,
# Г - 6,
# Д - 2,
# Е - 1

# %% [markdown]
# ### Задание. Реализуйте LeNet (3 балла)
#
# Если мы сделаем параметры сверток обучаемыми, то можем добиться хороших результатов для задач компьютерного зрения. Реализуйте архитектуру LeNet, предложенную еще в 1998 году!
# На этот раз используйте модульную структуру (без помощи класса Sequential).
#
# Наша нейронная сеть будет состоять из
# * Свёртки 3x3 (1 карта на входе, 6 на выходе) с активацией ReLU;
# * MaxPooling-а 2x2;
# * Свёртки 3x3 (6 карт на входе, 16 на выходе) с активацией ReLU;
# * MaxPooling-а 2x2;
# * Уплощения (nn.Flatten);
# * Полносвязного слоя со 120 нейронами и активацией ReLU;
# * Полносвязного слоя с 84 нейронами и активацией ReLU;
# * Выходного слоя из 10 нейронов.

# %%
class LeNet(nn.Module):
    def __init__(self):
        super(LeNet, self).__init__()
        # 1 input image channel, 6 output channels, 3x3 square conv kernel 28x28
        self.conv1 = nn.Conv2d(1, 6, 3, padding=1) # 28x28
        self.pool1 = nn.MaxPool2d(2) #YOUR CODE 14x14
        self.conv2 = nn.Conv2d(6, 16, 3) #YOUR CODE 12x12
        self.pool2 = nn.MaxPool2d(2) #YOUR CODE 6x6
        self.flatten = nn.Flatten()
        self.fc1 = nn.Linear(6*6*16, 120) #YOUR CODE  
        self.fc2 = nn.Linear(120, 84) #YOUR CODE
        self.fc3 = nn.Linear(84, 10) #YOUR CODE

    def forward(self, x):
        x = F.relu(self.conv1(x)) #YOUR CODE. Apply layers created in __init__. 
        x = self.pool1(x)
        x = F.relu(self.conv2(x))
        x = self.pool2(x)
        x = self.flatten(x)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

# %%
lenet = LeNet().to(device)

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(lenet.parameters())

loaders = {"train": train_dataloader, "valid": valid_dataloader}

# %% [markdown]
# ### Задание. Обучите CNN (3 балла)
# Используйте код обучения, который вы написали для полносвязной нейронной сети. Обратите внимание, что сверточная нейронная сеть будет обучаться дольше. Нейронную сеть необходимо обучить до стабилизации графика функции потерь на валидационной выборке! Для этого может потребоваться большое количество эпох.
#
# С какого-то момента качество на валидационной выборке начнет снова падать. В этот момент обучение можно прекращать.
#
# Обратите внимание, что если модель не успела сойтись и вам нужно большее количество эпох, модель можно не переобучать с нуля, а запустить с уже частично обученными весами. Подумайте, как это сделать в коде.
#
#
# Лучше запустить два эксперимента: на первом эксперименте оценить необходимое количество эпох, а на втором --- запустить обучение на таком количестве эпох и посчитать качество обученной модели на последней эпохе. Если бы в нашем распоряжении была тестовая выборка, можно было бы взять лучшую модель на валидации и вычислить ее качество на тесте.

# %%
def lenet(net=lenet):
    max_epochs = 10
    accuracy = {"train": [], "valid": []}
    for epoch in range(max_epochs):
        for k, dataloader in loaders.items():
            epoch_correct = 0
            epoch_all = 0
            for x_batch, y_batch in dataloader:
                x_batch = x_batch.to(device)
                y_batch = y_batch.to(device)
                if k == "train":
                    net.train()
                    optimizer.zero_grad()
                    outp = net(x_batch)
                 # YOUR CODE. Set model to ``train`` mode and calculate outputs. Don't forget zero_grad!
                else:
                    net.eval()
                    with torch.no_grad():
                        outp = net(x_batch) # YOUR CODE. Set model to ``eval`` mode and calculate outputs
                preds = outp.argmax(-1)
                correct = (preds == y_batch).sum() # YOUR CODE GOES HERE
                all = y_batch.size(0) # YOUR CODE GOES HERE
                epoch_correct += correct.item()
                epoch_all += all
                if k == "train":
                    loss = criterion(outp, y_batch)
                    loss.backward()
                    optimizer.step()
                # YOUR CODE. Calculate gradients and make a step of your optimizer
            if k == "train":
                print(f"Epoch: {epoch+1}")
            print(f"Loader: {k}. Accuracy: {epoch_correct/epoch_all}")
            accuracy[k].append(epoch_correct/epoch_all)

    return accuracy["valid"]

# %%
lenet_accuracy = lenet()
# Out:
# Epoch: 1
# Loader: train. Accuracy: 0.9949166666666667
# Loader: valid. Accuracy: 0.9867
# Epoch: 2
# Loader: train. Accuracy: 0.9951666666666666
# Loader: valid. Accuracy: 0.9883
# Epoch: 3
# Loader: train. Accuracy: 0.9959666666666667
# Loader: valid. Accuracy: 0.9899
# Epoch: 4
# Loader: train. Accuracy: 0.9966666666666667
# Loader: valid. Accuracy: 0.9892
# Epoch: 5
# Loader: train. Accuracy: 0.99625
# Loader: valid. Accuracy: 0.9872
# Epoch: 6
# Loader: train. Accuracy: 0.9973
# Loader: valid. Accuracy: 0.9888
# Epoch: 7
# Loader: train. Accuracy: 0.9975833333333334
# Loader: valid. Accuracy: 0.9883
# Epoch: 8
# Loader: train. Accuracy: 0.9973
# Loader: valid. Accuracy: 0.9887
# Epoch: 9
# Loader: train. Accuracy: 0.9970833333333333
# Loader: valid. Accuracy: 0.9884
# Epoch: 10
# Loader: train. Accuracy: 0.9981666666666666
# Loader: valid. Accuracy: 0.9888

# %% [markdown]
# Сравним с предыдущем пунктом

# %%
plt.figure(figsize=(16, 10))
plt.title("Valid accuracy")
plt.plot(range(max_epochs), relu_accuracy, label="ReLU activation", linewidth=2)
plt.plot(range(max_epochs), leaky_relu_accuracy, label="LeakyReLU activation", linewidth=2)
plt.plot(range(max_epochs), elu_accuracy, label="ELU activation", linewidth=2)
plt.plot(range(max_epochs), tanh_accuracy, label="Tanh activation", linewidth=2)
plt.plot(range(max_epochs), lenet_accuracy, label="LeNet", linewidth=2)
plt.legend()
plt.xlabel("Epoch")
plt.show()

# %% [markdown]
# **Вопрос 3**. Стабилизировалось ли качество вашей модели? Какая модель из всех обученных показала лучший результат?
#
# **Ответ:** стабилизировалось, лучше всех показала себя LeNet

# %% [markdown]
# **Вопрос 4**. Посчитайте accuracy после обучения с точностью до четырех знаков после запятой. Укажите качество с **последней** эпохи на валидационной выборке. **Обратите внимание, после перезапуска ноутбука перед отправкой на Stepik это число может измениться, так как есть небольшая случайная вариативность. Введите ответ, который дает итоговая версия вашего ноутбука.**

# %%
best_accuracy = lenet_accuracy[-1] # YOUR CODE
assert best_accuracy > 0.987, 'Модель недостаточно хорошая. Нужно лучше!'
